# %%
dict_p = {}
while True :
    a = input('이름 : ')
    if a == '':
        break
    b = int(input('개수 : '))
    if a in dict_p.keys():
        dict_p[a] += b
    else :
        dict_p[a] = b
print(dict_p)

for key,value in sorted(dict_p.items()):
    print(key,value,end=' ')
# Out:
# 이름 : 콜라
# 개수 : 10
# 이름 : 사이다
# 개수 : 15
# 이름 : 환타
# 개수 : 8
# 이름 :
# {'콜라': 10, '사이다': 15, '환타': 8}
# 사이다 15 콜라 10 환타 8

# %%
sort = sorted(dict_p.keys())
sort
c = sorted(dict_p.items())
c
# Out:
# [('사이다', 5), ('콜라', 3), ('환타', 10)]

# %%
set_wish = set(['새우깡','오감자','양파링','포카칩','양파링']) 
set_wish   ## 중복된 양파링 하나로 됨
# Out:
# {'새우깡', '양파링', '오감자', '포카칩'}

# %%
set_wish = {'새우깡','오감자','양파링','포카칩','양파링'}
set_wish   ## set 안쓰고 {}로도 집합 생성 가능
# Out:
# {'새우깡', '양파링', '오감자', '포카칩'}

# %%
## 집합 자료형은 순서가 없기 때문에 인덱싱으로 값을 얻을 수 없다.
## 인덱싱으로 접근하려면 리스트나 튜플로 변환하여 사용
set_wish = set(['새우깡','오감자','양파링','포카칩','양파링']) 
list_wish=list(set_wish)
print(list_wish)
print(list_wish[2])
# Out:
# ['오감자', '포카칩', '새우깡', '양파링']
# 새우깡

# %%
set_wish = set(['새우깡','오감자','양파링','포카칩','양파링']) 
list_wish=tuple(set_wish)
print(list_wish)
print(list_wish[2])
# Out:
# ('오감자', '포카칩', '새우깡', '양파링')
# 새우깡

# %%
## a와 b의 합집합 : a.union(b)   a|b
sweety = {'빼빼로','칸쵸','허니버터'}
salty = {'허니버터','포카칩','새우깡'}

print(sweety.union(salty))
print(sweety|salty)
# Out:
# {'칸쵸', '새우깡', '허니버터', '빼빼로', '포카칩'}
# {'칸쵸', '새우깡', '허니버터', '빼빼로', '포카칩'}

# %%
## a와 b의 교집합 : a.intersection(b)   a&b
print(sweety.intersection(salty))
print(sweety&salty)
# Out:
# {'허니버터'}
# {'허니버터'}

# %%
## a와 b의 차집합 : a.difference(b)   a-b
print(sweety.difference(salty))
print(sweety-salty)
# Out:
# {'빼빼로', '칸쵸'}
# {'빼빼로', '칸쵸'}

# %%
## 요소 추가 add
set_wish = {'새우깡','오감자','양파링','포카칩','양파링'}
set_wish.add('허니버터')
set_wish
# Out:
# {'새우깡', '양파링', '오감자', '포카칩', '허니버터'}

# %%
## 요소 추가 update
set_wish = {'새우깡','오감자','양파링','포카칩','양파링'}
set_wish.update(['빼빼로','칸쵸'])
set_wish
# Out:
# {'빼빼로', '새우깡', '양파링', '오감자', '칸쵸', '포카칩'}

# %%
## 요소 삭제 remove
set_wish = {'새우깡','오감자','양파링','포카칩','양파링'}
set_wish.remove('오감자')
set_wish
# Out:
# {'새우깡', '양파링', '포카칩'}

# %%
set_wish = {'새우깡','오감자','양파링','포카칩','양파링'}
if '새우깡' in list(set_wish):
    set_wish.remove('새우깡')
set_wish
# Out:
# {'양파링', '오감자', '포카칩'}

# %%
# NameError : 참조변수 없음
print(sadlj)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-e905e1a332df> in <module>()
# ----> 1 print(sadlj)
#
# NameError: name 'sadlj' is not defined

# %%
# SyntaxError : 문법이 잘못되었음 (오타,괄호,콜론(:)을 실수)
asdasd = 1:
print(asdasd)
# Out:
#   File "<ipython-input-40-e236fa0f8967>", line 2
#     asdasd = 1:
#               ^
# SyntaxError: invalid syntax

# %%
# TypeError : 타입이 맞지 않음
a,b = "1","1"
c = a-b  ## a와 b를 str로 정의 해놓음
c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-bcd73d747944> in <module>()
#       1 # TypeError : 타입이 맞지 않음
#       2 a,b = "1","1"
# ----> 3 c = a-b  ## a와 b를 str로 정의 해놓음
#       4 c
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
# ZeroDivisionError : 0으로 나눔
a,b = 1,0
c= a/b
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-44-df8cc84f4bbb> in <module>()
#       1 a,b = 1,0
# ----> 2 c= a/b
#
# ZeroDivisionError: division by zero

# %%
# IndentationError : 들여쓰기 오류
 print(1)
# Out:
#   File "<ipython-input-42-b519c9caead5>", line 2
#     print(1)
#     ^
# IndentationError: unexpected indent

# %%
a = 1
if a < 0:
    print('a는 0보다 작다.')
    print('a는 음수이다.')
print('끝')
# Out:
# 끝

# %%
a = 1
if a < 0:
    print('a는 0보다 작다.')
print('a는 음수이다.')  ## 들여쓰기 한 부분만 if문에 들어감
print('끝')
# Out:
# a는 음수이다.
# 끝

# %%
temp = float(input('체온 : '))
if temp > 37.5:
    print('등교불가')
else:
    print('등교가능')
# Out:
# 체온 : 37
# 등교가능

# %%
a=5
b=4
if a % b ==0:
    print(f'{a}는 {b}로 나누어 떨어집니다.')
else:
    print(f'{a}는 {b}로 나누면 나머지가 {a%b}입니다.')
# Out:
# 5는 4로 나누면 나머지가 1입니다.

# %%
a = float(input('체온 : '))  ## float 안붙이면 str값으로 입력돼서 a > 37.5에서 계산오류 
b = input('검사대기여부(y/n) : ')
c = input('자가격리여부(y/n) : ')
print('-'*50)
if a > 37.5:
    print('발열기준 초과 등교불가')
elif b == 'y':
    print('검사대기 중 등교불가')
elif c == 'y':
    print('자가격리 중 등교불가')
else:
    print('등교가능')
# Out:
# 체온 : 36
# 검사대기여부(y/n) : n
# 자가격리여부(y/n) : n
# --------------------------------------------------
# 등교가능

# %%
score = int(input('점수 : '))
if score >= 90:
    grade = 'A'
elif score >= 80:
    grade = 'B'
elif score >= 70:
    grade = 'C'
elif score >= 60:
    grade = 'D'
else:
    grade = 'F'
print(f'등급 : {grade}')
# Out:
# 점수 : 80
# 등급 : B

# %%
price = int(input('구매가(원) : '))
if price >= 100000:
    d = 0.1
elif price >= 50000:
    d = 0.075
elif price >= 10000:
    d = 0.05
else :
    d = 0
print(f'할인율 : {d*100}%')
print(f'지불금액(원) : {int(price*(1-d))}')
# Out:
# 구매가(원) : 77777
# 할인율 : 7.5%
# 지불금액(원) : 71943

# %%
n1 = int(input('수1 : '))
n2 = int(input('수2 : '))
n3 = int(input('수3 : '))

min1 = n1
if min1 > n2:
    min1 = n2
if min1 > n3:
    min1 = n3
print(min1)
# Out:
# 수1 : 3
# 수2 : 4
# 수3 : 5
# 3

# %%
1 in [1,2,3]
# Out:
# True

# %%
'a' not in ('a','b','c')
# Out:
# False

# %%
'j' not in 'python'
# Out:
# True

# %%
age = int(input('나이 : '))
if age >= 65:
    price = 0
elif age <= 7:
    price = 0
elif age <= 18:
    price = 1000
else :
    price = 3000
print(f'입장료는 {price}원입니다.')
# Out:
# 나이 : 8
# 입장료는 1000원입니다.

# %%
age = int(input('나이 : '))
if age >= 65 or age <= 7:
    price = 0
elif age <= 18:
    price = 1000
else :
    price = 3000
print(f'입장료는 {price}원입니다.')
# Out:
# 나이 : 8
# 입장료는 1000원입니다.

# %%
ID = 'a1234'
PW = '1q2w'

a = input('ID : ')
b = input('PW : ')

if a == ID and b == PW:
    print('로그인')
elif a != ID:
    print('아이디 불일치')
elif b != PW:
    print('패스워드 불일치')
# Out:
# ID : a1234
# PW : qq
# 패스워드 불일치

# %%
ID = 'a1234'
PW = '1q2w'

a = input('ID : ')
b = input('PW : ')

if a != ID or b != PW:
    print('로그인 실패')
else:
    print('로그인')
# Out:
# ID : a1234
# PW : 1q2w
# 로그인

# %%
num1 = int(input('숫자1 : '))
num2 = int(input('숫자2 : '))
cal = input('연산기호(+,-,*,/) : ')
if cal == '+':
    a = (num1 + num2)
elif cal == '-':
    a = (num1 - num2)
elif cal == '*':
    a = (num1 * num2)
elif num2 == 0:
    a = '무한대'
else:
    a = (num1 / num2)
print(f'{num1} {cal} {num2} = {a}')
# Out:
# 숫자1 : 12
# 숫자2 : 23
# 연산기호(+,-,*,/) : a
# 12 a 23 = 0.5217391304347826

# %%
num1 = int(input('숫자1 : '))
num2 = int(input('숫자2 : '))
cal = input('연산기호(+,-,*,/) : ')
if cal == '+':
    a = (num1 + num2)
elif cal == '-':
    a = (num1 - num2)
elif cal == '*':
    a = (num1 * num2)
elif cal == '/' and num2 == 0:
    print('0으로 나눌 수 없습니다.')
elif cal == '/':
    a = (num1 / num2)
    print(f'{num1} {cal} {num2} = {a}')
else:
    print('연산오류')
# Out:
# 숫자1 : 10
# 숫자2 : 0
# 연산기호(+,-,*,/) : /
# 0으로 나눌 수 없습니다.

# %%
## 임의의 정수 만들기
import random
random.randint(1,6) ## 1~6 사이의 임의의 정수
# Out:
# 6

# %%
dice1 = random.randint(1,6)
dice2 = random.randint(1,6)
if dice1 > dice2 :
    win = '주사위1'
elif dice1 < dice2 :
    win = '주사위2'
    print(f'{win}이 이겼습니다.')
else:
    print('무승부')
# Out:
# 주사위2이 이겼습니다.
